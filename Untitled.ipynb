# %%
# brain tumor classification 
# image X-RAY as input -> desicion about tymor from CNN

# Features:
# 1. Enable a GPU with "cuda"
# 2. Saving education progress
# 3. Saving weighs and baises
# 4. Want to see how looks beetween layers results

# 0. Setup enviroment
# 0.1. Set up libraries
# 0.2. Set up folders with images
# 0.3. Set up global names


# 1. About data
#    1.1 Importing data
#    1.2 Data destribution with grafic or pie chart # tran vs test # tumor vs no tumor 
# 2. Data normalisation and reshape
#    2.1. images into proper size reshape (might be with cv2 and contours) 
#    2.2. data separation to train and test

# 3. chosing data model and setup
#     3.1 Batch_size to choose
#     3.2 Adam parameters
#     3.3 Dropout 
#     4.1 between education accuracy result
#   conv 32, 4,4 
#   conv 64, 4,4
#   conv 128,4,4
#   conv 128,4,4
#   512 input Neurons
#   4 hidden layer
#   1 output with 0/1 - has tumor or not - softmax activation

# Train CNN
# show training results, model performance

# Avaluate model 
# confusion matrix

# model results accuracy

# %%
import os, sys
import glob
import numpy as np
import matplotlib.pyplot as plt

import cv2

from tensorflow import keras
from tensorflow.keras import layers

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
dir_path = os.getcwd()
file_path = fr"{dir_path}\\train.csv"
positive_tumor_path = fr"{dir_path}\\brain_tumor_dataset\\yes\\*.*"
negative_tumor_path = fr"{dir_path}\\brain_tumor_dataset\\no\\*.*"
docs_images_path = fr"{dir_path}\\docs"

# %%
# 1. About data

train_tumor_images_path = []

train_tumor_images = []
goal_tumor_images = []

for filename in glob.glob(positive_tumor_path):
    train_tumor_images_path.append([filename, 1])

for filename in glob.glob(negative_tumor_path):
    train_tumor_images_path.append([filename, 0])

# %%
# 2. Data normalisation and reshape

# Read an image using OpenCV
# Apply a Gaussian blur
# Find the biggest contour
# Get its extreme points (top, bottom, left, right)
# Crop the image by those extremes
# Here’s a complete, step-by-step Python code


# imortant!!! chech if all sizes are aprocimtly same 

x_height = []
y_weight = []


def biggest_contours_extrems(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    _, thresh = cv2.threshold(blur, 150, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    max_contour = max(contours, key=cv2.contourArea)
    
    ext_left = tuple(max_contour[max_contour[:, :, 0].argmin()][0])
    ext_right = tuple(max_contour[max_contour[:, :, 0].argmax()][0])
    ext_top = tuple(max_contour[max_contour[:, :, 1].argmin()][0])
    ext_bottom = tuple(max_contour[max_contour[:, :, 1].argmax()][0])
    
    x_min = ext_left[0]
    x_max = ext_right[0]
    y_min = ext_top[1]
    y_max = ext_bottom[1]

    return x_min, x_max, y_min, y_max, thresh


for image_path in train_tumor_images_path:
    #print(image_path)
    img = cv2.imread(image_path[0])
    status = image_path[1]
 
    x_min, x_max, y_min, y_max, thresh = biggest_contours_extrems(img)

    cropped = img[y_min:y_max, x_min:x_max]

    bordered = cv2.copyMakeBorder(
    cropped,
    top=1, bottom=1, left=1, right=1,
    borderType=cv2.BORDER_CONSTANT,
    value=(0, 0, 0))

    img_resized = cv2.resize(bordered, (224, 224))

    train_tumor_images.append(img_resized)
    goal_tumor_images.append(status)

    x_min, x_max, y_min, y_max, _ = biggest_contours_extrems(img_resized)
    
    # chech size of skull - contour after reshape and resize -> should be approx same pixel size 

    weight, height,= x_max - x_min, y_max - y_min
    x_height.append(height)
    y_weight.append(weight)
    
    # Convert BGR → RGB for matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cropped_rgb = cv2.cvtColor(cropped, cv2.COLOR_BGR2RGB)

    plt.scatter(x_height, y_weight, color='red', s=50, alpha = 0.6)
    plt.xlabel("Image height")
    plt.ylabel("Image weight")

    
plt.show()

# %%
train_tumor_images_pure = np.array([train_tumor_images]).T
goal_tumor_images_pure = np.array(goal_tumor_images)

print(train_tumor_images_pure.shape)
print(goal_tumor_images_pure.shape)

# 1️⃣ Перемістимо осі, щоб перший індекс був кількістю зразків
X = np.moveaxis(train_tumor_images_pure, [0, 1, 2, 3, 4], [3, 1, 2, 0, 4])
Y = goal_tumor_images_pure


# will keep test data as a path to picture to save memory space
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

X_train = X_train.astype('float32') / 255.0
X_test  = X_test.astype('float32') / 255.0
# Out:
# (3, 224, 224, 253, 1)
# (253,)
# Same shape:  False

# %%
#1.2 Data destribution with grafic or pie chart # tran vs test # tumor vs no tumor 

def autopct_format(pct, allvals):
    absolute = int(round(pct/100.*sum(allvals)))
    return f"{pct:.1f}%\n({absolute})"

fig, axes = plt.subplots(ncols=2, figsize=(20, 5))

labels = ['positive tumor', 'negative tumor']
sizes = [len(glob.glob(positive_tumor_path)), len(glob.glob(negative_tumor_path))]
colors = ['#ff9999','#66b3ff']
explode = (0.1, 0)

axes[0].pie(sizes, labels=labels, colors=colors, 
        autopct= lambda pct: autopct_format(pct, sizes),
        startangle=90, explode=explode, shadow=True)

axes[0].set_xlabel('Data sample destribution')
axes[0].axis('equal')

labels = ['Train data', 'Test data']
sizes = [len(X_train), len(X_test)]
colors = ['#ff9999','#66b3ff']
explode = (0, 0)

axes[1].pie(sizes, labels=labels, colors=colors, 
            autopct= lambda pct: autopct_format(pct, sizes),
        startangle=90, explode=explode, shadow=True)

axes[1].set_xlabel('Data sample destribution')
axes[1].axis('equal')

plt.show()

# %%
# 3. chosing data model and setup
# typical architecture: Conv → Conv → Pool → Conv → Pool → Conv → Pool → Flatten → Dense

# 3. chosing data model and setup
#     3.1 Batch_size to choose                  Done
#     3.2 Adam parameters                       Done
#     3.3 Dropout                               Done
#     4.1 between education accuracy result     Done

def build_cnn(input_shape=(224, 224, 3)):  # розмір зображення 224х224, 3 канали (RGB)
    model = models.Sequential([
        layers.Conv2D(32, (4, 4), activation='relu', padding='same', input_shape=input_shape),

        # 1 згортковий блок
        layers.Conv2D(64, (4, 4), activation='relu', padding='same'),
        layers.SpatialDropout2D(0.25),
        layers.MaxPooling2D((2, 2)),

        # 2 згортковий блок
        layers.Conv2D(128, (4, 4), activation='relu', padding='same'),
        layers.SpatialDropout2D(0.25),
        layers.MaxPooling2D((2, 2)),

        # 3 згортковий блок
        layers.Conv2D(128, (4, 4), activation='relu', padding='same'),
        layers.SpatialDropout2D(0.25),
        layers.MaxPooling2D((2, 2)),
        
        layers.Flatten(),
        
        # layers.Dense(512, activation='relu'), # fully connected layer
        # layers.Dropout(0.2),
            
        # layers.Dense(64, activation='relu'), # fully connected layer
        # layers.Dropout(0.2),
        # layers.Dense(4, activation='relu'),
        # layers.Dense(1, activation='sigmoid')  # 1 вихід — для binary classification


        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model



model = build_cnn()
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 224, 224, 32)        │           1,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 224, 224, 64)        │          32,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout2d_3                  │ (None, 224, 224, 64)        │               0 │
# │ (SpatialDropout2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 112, 112, 128)       │         131,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout2d_4                  │ (None, 112, 112, 128)       │               0 │
# │ (SpatialDropout2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 56, 56, 128)         │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout2d_5                  │ (None, 56, 56, 128)         │               0 │
# │ (SpatialDropout2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 100352)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 256)                 │      25,690,368 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,118,497 (99.63 MB)
#  Trainable params: 26,118,497 (99.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)
]

# %%
history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=100,
                    batch_size=32)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.4845 - loss: 163.5095 - val_accuracy: 0.5854 - val_loss: 16.9409
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.5776 - loss: 6.4636 - val_accuracy: 0.5854 - val_loss: 0.6712
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6025 - loss: 0.6720 - val_accuracy: 0.5854 - val_loss: 0.6783
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.5652 - loss: 0.7027 - val_accuracy: 0.6098 - val_loss: 0.6767
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.6460 - loss: 0.6502 - val_accuracy: 0.5854 - val_loss: 0.6741
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.6584 - loss: 0.6831 - val_accuracy: 0.5854 - val_loss: 0.6748
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6211 - loss: 0.6691 - val_accuracy: 0.5854 - val_loss: 0.6734
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6087 - loss: 0.6650 - val_accuracy: 0.5854 - val_loss: 0.6675
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6460 - loss: 0.6363 - val_accuracy: 0.5854 - val_loss: 0.6622
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6460 - loss: 0.6223 - val_accuracy: 0.5854 - val_loss: 0.6546
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.6584 - loss: 0.6383 - val_accuracy: 0.5854 - val_loss: 0.6484
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6460 - loss: 0.6162 - val_accuracy: 0.5854 - val_loss: 0.6516
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.6522 - loss: 0.6052 - val_accuracy: 0.5854 - val_loss: 0.6560
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6708 - loss: 0.5880 - val_accuracy: 0.6098 - val_loss: 0.6576
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.6335 - loss: 0.6537 - val_accuracy: 0.5854 - val_loss: 0.6360
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.6335 - loss: 0.6232 - val_accuracy: 0.5854 - val_loss: 0.6198
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6522 - loss: 0.5934 - val_accuracy: 0.5854 - val_loss: 0.6182
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6211 - loss: 0.6135 - val_accuracy: 0.5854 - val_loss: 0.6064
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.6832 - loss: 0.5855 - val_accuracy: 0.6098 - val_loss: 0.5774
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6708 - loss: 0.5715 - val_accuracy: 0.5854 - val_loss: 0.6258
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.7081 - loss: 0.5702 - val_accuracy: 0.6585 - val_loss: 0.5957
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6584 - loss: 0.6531 - val_accuracy: 0.6829 - val_loss: 0.6272
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.7081 - loss: 0.5524 - val_accuracy: 0.6585 - val_loss: 0.6912
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.6957 - loss: 0.5882 - val_accuracy: 0.6829 - val_loss: 0.7098
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.6957 - loss: 0.5354 - val_accuracy: 0.7561 - val_loss: 0.6168
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.7205 - loss: 0.5733 - val_accuracy: 0.7561 - val_loss: 0.6241
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.6894 - loss: 0.5445 - val_accuracy: 0.6829 - val_loss: 0.6705
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.6770 - loss: 0.5994 - val_accuracy: 0.6098 - val_loss: 0.7220
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.7205 - loss: 0.5303 - val_accuracy: 0.6098 - val_loss: 0.6937
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.7453 - loss: 0.5208 - val_accuracy: 0.7073 - val_loss: 0.6258
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.7764 - loss: 0.4503 - val_accuracy: 0.6829 - val_loss: 0.8035
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.7640 - loss: 0.4826 - val_accuracy: 0.6829 - val_loss: 0.8307
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.7950 - loss: 0.4021 - val_accuracy: 0.7073 - val_loss: 0.5767
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.8012 - loss: 0.4427 - val_accuracy: 0.7805 - val_loss: 0.5198
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.8199 - loss: 0.4182 - val_accuracy: 0.7073 - val_loss: 0.5922
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.7826 - loss: 0.4558 - val_accuracy: 0.6829 - val_loss: 0.6385
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.8012 - loss: 0.4181 - val_accuracy: 0.7561 - val_loss: 0.5140
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.8447 - loss: 0.3052 - val_accuracy: 0.8049 - val_loss: 0.5866
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.8261 - loss: 0.3747 - val_accuracy: 0.7805 - val_loss: 0.5595
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.8696 - loss: 0.2955 - val_accuracy: 0.7561 - val_loss: 0.6231
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.8882 - loss: 0.2470 - val_accuracy: 0.8049 - val_loss: 0.6110
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.8820 - loss: 0.2234 - val_accuracy: 0.8293 - val_loss: 0.5825
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.8758 - loss: 0.2624 - val_accuracy: 0.8293 - val_loss: 0.5450
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.8634 - loss: 0.2624 - val_accuracy: 0.8049 - val_loss: 0.6467
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9006 - loss: 0.2102 - val_accuracy: 0.8293 - val_loss: 0.5960
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9130 - loss: 0.2444 - val_accuracy: 0.8293 - val_loss: 0.5996
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.8820 - loss: 0.2446 - val_accuracy: 0.7805 - val_loss: 0.8891
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.9255 - loss: 0.1533 - val_accuracy: 0.8049 - val_loss: 1.2006
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.9255 - loss: 0.1808 - val_accuracy: 0.8049 - val_loss: 1.2499
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9317 - loss: 0.1784 - val_accuracy: 0.8049 - val_loss: 1.0637
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9130 - loss: 0.1710 - val_accuracy: 0.8049 - val_loss: 0.9880
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9255 - loss: 0.1990 - val_accuracy: 0.8049 - val_loss: 1.0723
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9689 - loss: 0.1018 - val_accuracy: 0.8049 - val_loss: 1.0732
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.9130 - loss: 0.1767 - val_accuracy: 0.8049 - val_loss: 1.1304
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9503 - loss: 0.1131 - val_accuracy: 0.8293 - val_loss: 1.0550
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9503 - loss: 0.0990 - val_accuracy: 0.8537 - val_loss: 1.0496
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.8820 - loss: 0.2348 - val_accuracy: 0.8049 - val_loss: 1.1965
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 44s 5s/step - accuracy: 0.9006 - loss: 0.2259 - val_accuracy: 0.8049 - val_loss: 1.0428
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9317 - loss: 0.1799 - val_accuracy: 0.7561 - val_loss: 1.0742
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9379 - loss: 0.1398 - val_accuracy: 0.7805 - val_loss: 1.1484
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9565 - loss: 0.1122 - val_accuracy: 0.7561 - val_loss: 1.3406
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9130 - loss: 0.1501 - val_accuracy: 0.8049 - val_loss: 1.5549
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9565 - loss: 0.0806 - val_accuracy: 0.8293 - val_loss: 1.6976
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9627 - loss: 0.1012 - val_accuracy: 0.8293 - val_loss: 1.6298
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9317 - loss: 0.1375 - val_accuracy: 0.8049 - val_loss: 1.5738
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.9379 - loss: 0.1132 - val_accuracy: 0.8293 - val_loss: 1.6008
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9379 - loss: 0.0948 - val_accuracy: 0.8293 - val_loss: 1.0682
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9379 - loss: 0.1114 - val_accuracy: 0.8293 - val_loss: 1.0302
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9441 - loss: 0.1267 - val_accuracy: 0.8293 - val_loss: 1.4199
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9441 - loss: 0.0991 - val_accuracy: 0.8293 - val_loss: 1.7852
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9379 - loss: 0.1138 - val_accuracy: 0.8049 - val_loss: 2.0484
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9627 - loss: 0.1064 - val_accuracy: 0.8293 - val_loss: 1.7657
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9627 - loss: 0.0930 - val_accuracy: 0.8293 - val_loss: 1.5954
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9814 - loss: 0.0440 - val_accuracy: 0.8049 - val_loss: 1.5230
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.9627 - loss: 0.0749 - val_accuracy: 0.8537 - val_loss: 1.5219
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9876 - loss: 0.0461 - val_accuracy: 0.8537 - val_loss: 1.6340
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9752 - loss: 0.0546 - val_accuracy: 0.8293 - val_loss: 1.8400
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9627 - loss: 0.0504 - val_accuracy: 0.8293 - val_loss: 2.0434
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9689 - loss: 0.0572 - val_accuracy: 0.8293 - val_loss: 2.4108
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 4s/step - accuracy: 0.9876 - loss: 0.0400 - val_accuracy: 0.8049 - val_loss: 2.7880
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9689 - loss: 0.0640 - val_accuracy: 0.8537 - val_loss: 1.9736
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9814 - loss: 0.0793 - val_accuracy: 0.8537 - val_loss: 1.5415
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9876 - loss: 0.0869 - val_accuracy: 0.8537 - val_loss: 1.3229
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9876 - loss: 0.0452 - val_accuracy: 0.8537 - val_loss: 1.4164
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9876 - loss: 0.0305 - val_accuracy: 0.8537 - val_loss: 1.5776
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9938 - loss: 0.0306 - val_accuracy: 0.8537 - val_loss: 1.8394
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9876 - loss: 0.0286 - val_accuracy: 0.8537 - val_loss: 2.0646
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9876 - loss: 0.0455 - val_accuracy: 0.8537 - val_loss: 1.4929
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9689 - loss: 0.0670 - val_accuracy: 0.8049 - val_loss: 1.4288
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9938 - loss: 0.0174 - val_accuracy: 0.8293 - val_loss: 1.4768
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9938 - loss: 0.0237 - val_accuracy: 0.8537 - val_loss: 1.5308
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9814 - loss: 0.0222 - val_accuracy: 0.8780 - val_loss: 1.5589
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9876 - loss: 0.0576 - val_accuracy: 0.8780 - val_loss: 1.5276
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.9938 - loss: 0.0154 - val_accuracy: 0.8780 - val_loss: 1.5171
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.8780 - val_loss: 1.5629
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9876 - loss: 0.0224 - val_accuracy: 0.8780 - val_loss: 1.6668
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9938 - loss: 0.0396 - val_accuracy: 0.8780 - val_loss: 1.8631
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9689 - loss: 0.0691 - val_accuracy: 0.8780 - val_loss: 1.4999
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 0.9938 - loss: 0.0241 - val_accuracy: 0.8780 - val_loss: 1.5638
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.8780 - val_loss: 1.6277

# %%
# Можна передавати також validation_split=0.2 замість явних масивів (Keras розіб’є частину тренувальних даних на валідацію).
# Ідеальний сценарій:
# loss → плавно зменшується
# val_loss → зменшується або стабілізується
# accuracy → росте
# val_accuracy → росте або тримається близько до accuracy

# Поганий сценарій (overfitting):
# loss продовжує зменшуватись
# val_loss починає рости
# accuracy зростає, а val_accuracy падає → модель “запам’ятовує” тренувальні приклади

# Adaptive Moment Estimation
# Тобто Adam — це "розумний" оптимізатор,
# який автоматично підлаштовує learning rate під кожен параметр моделі.
# Без Dropout мережа може:
# "запам’ятати" тренувальні дані (overfitting)
# покладатись надто сильно на конкретні нейрони або зв’язки

# %%
fig, axes = plt.subplots(ncols=2, figsize=(20, 5))

axes[0].plot(history.history['accuracy'], label='Train accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation accuracy')

axes[0].legend()
#axes[0].title("Accuracy training")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")


axes[1].plot(history.history['val_loss'][10:], label='Validation loss')
axes[1].plot(history.history['loss'][10:], label='loss')
axes[1].legend()
#axes[1].title("loss training")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("loss")


plt.show()

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"📊 Test accuracy: {test_accuracy:.4f}")
print(f"📉 Test loss: {test_loss:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 602ms/step - accuracy: 0.7059 - loss: 2.5963
# 📊 Test accuracy: 0.7059
# 📉 Test loss: 2.5963

# %%
y_pred = model.predict(X_test)
y_pred_labels = (y_pred > 0.5).astype(int)

# confusion matrix plot
cm = confusion_matrix(y_test, y_pred_labels, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Tumor", "NO Tumor", ])
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.savefig(fr"{dir_path}\docs\confusion_matrix.png", dpi=300, bbox_inches="tight")
plt.show()

print("Accuracy:", accuracy_score(y_test, y_pred_labels))
print("Classification report:\n", classification_report(y_test, y_pred_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 573ms/step
# Accuracy: 0.7058823529411765
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.54      0.63        24
#            1       0.68      0.85      0.75        27
#
#     accuracy                           0.71        51
#    macro avg       0.72      0.70      0.69        51
# weighted avg       0.72      0.71      0.70        51

# %%
incorrect = np.where(y_pred_labels.flatten() != y_test.flatten())[0]

for i in incorrect[:5]:
    test_image = X_test[i]
    test_image = np.squeeze(test_image, axis=-1)
    plt.imshow(test_image)
    plt.title(f"True: {y_test[i]}, Predicted: {y_pred_labels[i][0]}")
    plt.show()
